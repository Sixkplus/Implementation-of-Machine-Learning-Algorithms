# %% [markdown]
# # Neural Networks
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **forward** and **backward** operations for different layers in neural networks
# - implement a simple neural networks for classification
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
digit_data = sio.loadmat('digit_data.mat')
X = digit_data['X']
y = digit_data['y']
_, num_cases = X.shape
train_num_cases = num_cases * 4 // 5
X = X.reshape((400, num_cases))
X = X.transpose()
# X has the shape of (number of samples, number of pixels)
train_data = X[:train_num_cases,:]
train_label = y[:, :train_num_cases]
test_data = X[train_num_cases:, :]
test_label = y[:, train_num_cases:]
weights = {}
weights['fully1_weight'] = np.random.randn(400, 25) / 400
weights['fully1_bias'] = np.random.rand(25, 1) 
weights['fully2_weight'] = np.random.randn(25, 10) / 25
weights['fully2_bias'] = np.random.rand(10, 1)

# %% [markdown]
# ## Training

# %%
# training setting
weight_inc = {}
for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
    weight_inc[name] = np.zeros(weights[name].shape)
batch_size = 100
max_epoch = 10
momW = 0.9
wc = 0.0005
learning_rate = 0.1

# Training iterations
from get_new_weight_inc import get_new_weight_inc
from feedforward_backprop import feedforward_backprop

for epoch in range(max_epoch):
    for i in range(math.ceil(train_num_cases/batch_size)):
        data = train_data[i * batch_size:min((i + 1) * batch_size, train_num_cases), :]
        label = train_label[:, i * batch_size:min((i + 1) * batch_size, train_num_cases)]
        # The feedforward and backpropgation processes
        loss, accuracy, gradients = feedforward_backprop(data, label, weights)
        print('{:3}.{:2} loss:{:.3}, accuracy:{}'.format(epoch + 1, i + 1, loss, accuracy))
        # Updating weights
        for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
            #print(name)
            weight_inc[name] = get_new_weight_inc(weight_inc[name], weights[name], momW, wc, learning_rate, gradients[name + '_grad'])
            #print(weights[name].shape, weight_inc[name].shape, gradients[name + '_grad'].shape)
            weights[name] += weight_inc[name]
# Out:
#   1. 1 loss:0.0552, accuracy:0.99
#   1. 2 loss:0.106, accuracy:0.99
#   1. 3 loss:0.0636, accuracy:0.99
#   1. 4 loss:0.123, accuracy:0.97
#   1. 5 loss:0.122, accuracy:0.96
#   1. 6 loss:0.0464, accuracy:1.0
#   1. 7 loss:0.0929, accuracy:0.98
#   1. 8 loss:0.0633, accuracy:0.99
#   1. 9 loss:0.0527, accuracy:0.98
#   1.10 loss:0.109, accuracy:0.95
#   1.11 loss:0.0971, accuracy:0.96
#   1.12 loss:0.147, accuracy:0.97
#   1.13 loss:0.136, accuracy:0.95
#   1.14 loss:0.168, accuracy:0.97
#   1.15 loss:0.0278, accuracy:1.0
#   1.16 loss:0.0965, accuracy:0.98
#   1.17 loss:0.0967, accuracy:0.97
#   1.18 loss:0.152, accuracy:0.94
#   1.19 loss:0.164, accuracy:0.96
#   1.20 loss:0.0901, accuracy:0.98
#   1.21 loss:0.0806, accuracy:0.98
#   1.22 loss:0.129, accuracy:0.93
#   1.23 loss:0.108, accuracy:0.98
#   1.24 loss:0.0955, accuracy:0.96
#   1.25 loss:0.0784, accuracy:0.97
#   1.26 loss:0.0772, accuracy:0.99
#   1.27 loss:0.141, accuracy:0.94
#   1.28 loss:0.0964, accuracy:0.97
#   1.29 loss:0.122, accuracy:0.95
#   1.30 loss:0.093, accuracy:0.98
#   1.31 loss:0.131, accuracy:0.96
#   1.32 loss:0.0713, accuracy:1.0
#   1.33 loss:0.153, accuracy:0.94
#   1.34 loss:0.137, accuracy:0.96
#   1.35 loss:0.227, accuracy:0.93
#   1.36 loss:0.121, accuracy:0.96
#   1.37 loss:0.118, accuracy:0.95
#   1.38 loss:0.0995, accuracy:0.98
#   1.39 loss:0.171, accuracy:0.95
#   1.40 loss:0.256, accuracy:0.94
#   2. 1 loss:0.0422, accuracy:1.0
#   2. 2 loss:0.0897, accuracy:0.99
#   2. 3 loss:0.06, accuracy:1.0
#   2. 4 loss:0.103, accuracy:0.98
#   2. 5 loss:0.155, accuracy:0.94
#   2. 6 loss:0.0487, accuracy:1.0
#   2. 7 loss:0.109, accuracy:0.96
#   2. 8 loss:0.0684, accuracy:0.98
#   2. 9 loss:0.052, accuracy:0.99
#   2.10 loss:0.127, accuracy:0.95
#   2.11 loss:0.0897, accuracy:0.98
#   2.12 loss:0.146, accuracy:0.96
#   2.13 loss:0.157, accuracy:0.94
#   2.14 loss:0.163, accuracy:0.96
#   2.15 loss:0.0312, accuracy:1.0
#   2.16 loss:0.11, accuracy:0.97
#   2.17 loss:0.108, accuracy:0.94
#   2.18 loss:0.138, accuracy:0.95
#   2.19 loss:0.16, accuracy:0.96
#   2.20 loss:0.0883, accuracy:0.98
#   2.21 loss:0.0764, accuracy:0.98
#   2.22 loss:0.0868, accuracy:0.98
#   2.23 loss:0.106, accuracy:0.97
#   2.24 loss:0.0867, accuracy:0.97
#   2.25 loss:0.073, accuracy:0.98
#   2.26 loss:0.0756, accuracy:0.99
#   2.27 loss:0.127, accuracy:0.97
#   2.28 loss:0.0912, accuracy:0.97
#   2.29 loss:0.109, accuracy:0.95
#   2.30 loss:0.0794, accuracy:0.98
#   2.31 loss:0.115, accuracy:0.96
#   2.32 loss:0.0691, accuracy:1.0
#   2.33 loss:0.138, accuracy:0.95
#   2.34 loss:0.12, accuracy:0.97
#   2.35 loss:0.229, accuracy:0.94
#   2.36 loss:0.113, accuracy:0.96
#   2.37 loss:0.0973, accuracy:0.98
#   2.38 loss:0.0862, accuracy:0.98
#   2.39 loss:0.156, accuracy:0.95
#   2.40 loss:0.219, accuracy:0.95
#   3. 1 loss:0.0367, accuracy:1.0
#   3. 2 loss:0.0828, accuracy:0.98
#   3. 3 loss:0.0475, accuracy:1.0
#   3. 4 loss:0.0832, accuracy:0.98
#   3. 5 loss:0.136, accuracy:0.95
#   3. 6 loss:0.0447, accuracy:1.0
#   3. 7 loss:0.104, accuracy:0.97
#   3. 8 loss:0.0562, accuracy:1.0
#   3. 9 loss:0.0558, accuracy:0.99
#   3.10 loss:0.124, accuracy:0.95
#   3.11 loss:0.087, accuracy:0.99
#   3.12 loss:0.121, accuracy:0.97
#   3.13 loss:0.136, accuracy:0.96
#   3.14 loss:0.141, accuracy:0.95
#   3.15 loss:0.033, accuracy:1.0
#   3.16 loss:0.103, accuracy:0.97
#   3.17 loss:0.103, accuracy:0.95
#   3.18 loss:0.147, accuracy:0.94
#   3.19 loss:0.142, accuracy:0.96
#   3.20 loss:0.0776, accuracy:0.99
#   3.21 loss:0.0753, accuracy:0.98
#   3.22 loss:0.0892, accuracy:0.97
#   3.23 loss:0.0955, accuracy:0.98
#   3.24 loss:0.0752, accuracy:0.98
#   3.25 loss:0.0705, accuracy:0.99
#   3.26 loss:0.0788, accuracy:0.99
#   3.27 loss:0.115, accuracy:0.98
#   3.28 loss:0.0987, accuracy:0.98
#   3.29 loss:0.117, accuracy:0.95
#   3.30 loss:0.0821, accuracy:0.99
#   3.31 loss:0.0966, accuracy:0.98
#   3.32 loss:0.0716, accuracy:1.0
#   3.33 loss:0.129, accuracy:0.98
#   3.34 loss:0.109, accuracy:0.97
#   3.35 loss:0.206, accuracy:0.95
#   3.36 loss:0.105, accuracy:0.96
#   3.37 loss:0.101, accuracy:0.97
#   3.38 loss:0.0781, accuracy:0.98
#   3.39 loss:0.141, accuracy:0.96
#   3.40 loss:0.2, accuracy:0.95
#   4. 1 loss:0.0335, accuracy:1.0
#   4. 2 loss:0.0716, accuracy:0.99
#   4. 3 loss:0.041, accuracy:1.0
#   4. 4 loss:0.0808, accuracy:0.98
#   4. 5 loss:0.113, accuracy:0.97
#   4. 6 loss:0.045, accuracy:1.0
#   4. 7 loss:0.0941, accuracy:0.98
#   4. 8 loss:0.0497, accuracy:1.0
#   4. 9 loss:0.0535, accuracy:0.99
#   4.10 loss:0.118, accuracy:0.95
#   4.11 loss:0.0843, accuracy:0.99
#   4.12 loss:0.117, accuracy:0.96
#   4.13 loss:0.125, accuracy:0.95
#   4.14 loss:0.125, accuracy:0.96
#   4.15 loss:0.0263, accuracy:1.0
#   4.16 loss:0.0986, accuracy:0.97
#   4.17 loss:0.0901, accuracy:0.97
#   4.18 loss:0.145, accuracy:0.94
#   4.19 loss:0.132, accuracy:0.96
#   4.20 loss:0.0708, accuracy:0.99
#   4.21 loss:0.0731, accuracy:0.98
#   4.22 loss:0.0994, accuracy:0.96
#   4.23 loss:0.0821, accuracy:0.98
#   4.24 loss:0.0698, accuracy:0.98
#   4.25 loss:0.0573, accuracy:1.0
#   4.26 loss:0.0663, accuracy:0.99
#   4.27 loss:0.0939, accuracy:0.98
#   4.28 loss:0.0957, accuracy:0.98
#   4.29 loss:0.117, accuracy:0.95
#   4.30 loss:0.0849, accuracy:0.98
#   4.31 loss:0.0906, accuracy:0.98
#   4.32 loss:0.0749, accuracy:1.0
#   4.33 loss:0.127, accuracy:0.96
#   4.34 loss:0.0973, accuracy:0.97
#   4.35 loss:0.19, accuracy:0.97
#   4.36 loss:0.0796, accuracy:0.99
#   4.37 loss:0.0929, accuracy:0.97
#   4.38 loss:0.0709, accuracy:1.0
#   4.39 loss:0.135, accuracy:0.96
#   4.40 loss:0.2, accuracy:0.95
#   5. 1 loss:0.0309, accuracy:1.0
#   5. 2 loss:0.0658, accuracy:0.99
#   5. 3 loss:0.0374, accuracy:1.0
#   5. 4 loss:0.089, accuracy:0.96
#   5. 5 loss:0.0873, accuracy:0.98
#   5. 6 loss:0.037, accuracy:1.0
#   5. 7 loss:0.0804, accuracy:0.96
#   5. 8 loss:0.0465, accuracy:1.0
#   5. 9 loss:0.0591, accuracy:0.99
#   5.10 loss:0.13, accuracy:0.95
#   5.11 loss:0.0829, accuracy:0.98
#   5.12 loss:0.121, accuracy:0.96
#   5.13 loss:0.121, accuracy:0.95
#   5.14 loss:0.126, accuracy:0.96
#   5.15 loss:0.0228, accuracy:1.0
#   5.16 loss:0.0953, accuracy:0.97
#   5.17 loss:0.0755, accuracy:0.96
#   5.18 loss:0.125, accuracy:0.96
#   5.19 loss:0.129, accuracy:0.97
#   5.20 loss:0.0666, accuracy:0.99
#   5.21 loss:0.0701, accuracy:0.98
#   5.22 loss:0.105, accuracy:0.97
#   5.23 loss:0.0754, accuracy:0.98
#   5.24 loss:0.0698, accuracy:0.98
#   5.25 loss:0.0495, accuracy:1.0
#   5.26 loss:0.0589, accuracy:0.99
#   5.27 loss:0.0796, accuracy:0.99
#   5.28 loss:0.0872, accuracy:0.98
#   5.29 loss:0.102, accuracy:0.96
#   5.30 loss:0.0811, accuracy:0.98
#   5.31 loss:0.0936, accuracy:0.98
#   5.32 loss:0.0725, accuracy:1.0
#   5.33 loss:0.134, accuracy:0.96
#   5.34 loss:0.0941, accuracy:0.97
#   5.35 loss:0.182, accuracy:0.96
#   5.36 loss:0.0642, accuracy:0.99
#   5.37 loss:0.081, accuracy:0.99
#   5.38 loss:0.0615, accuracy:1.0
#   5.39 loss:0.122, accuracy:0.96
#   5.40 loss:0.187, accuracy:0.95
#   6. 1 loss:0.0347, accuracy:1.0
#   6. 2 loss:0.0754, accuracy:0.98
#   6. 3 loss:0.0431, accuracy:0.99
#   6. 4 loss:0.0942, accuracy:0.97
#   6. 5 loss:0.0768, accuracy:0.98
#   6. 6 loss:0.0309, accuracy:1.0
#   6. 7 loss:0.0664, accuracy:0.98
#   6. 8 loss:0.039, accuracy:1.0
#   6. 9 loss:0.0598, accuracy:0.99
#   6.10 loss:0.128, accuracy:0.96
#   6.11 loss:0.0765, accuracy:0.98
#   6.12 loss:0.12, accuracy:0.96
#   6.13 loss:0.124, accuracy:0.95
#   6.14 loss:0.139, accuracy:0.96
#   6.15 loss:0.0226, accuracy:1.0
#   6.16 loss:0.0854, accuracy:0.98
#   6.17 loss:0.0629, accuracy:0.98
#   6.18 loss:0.0901, accuracy:0.98
#   6.19 loss:0.123, accuracy:0.97
#   6.20 loss:0.073, accuracy:1.0
#   6.21 loss:0.0733, accuracy:0.98
#   6.22 loss:0.108, accuracy:0.98
#   6.23 loss:0.0712, accuracy:0.98
#   6.24 loss:0.0782, accuracy:0.99
#   6.25 loss:0.0408, accuracy:1.0
#   6.26 loss:0.0582, accuracy:0.97
#   6.27 loss:0.0826, accuracy:0.98
#   6.28 loss:0.0745, accuracy:0.98
#   6.29 loss:0.0894, accuracy:0.98
#   6.30 loss:0.069, accuracy:0.98
#   6.31 loss:0.0829, accuracy:0.99
#   6.32 loss:0.0623, accuracy:1.0
#   6.33 loss:0.131, accuracy:0.96
#   6.34 loss:0.103, accuracy:0.96
#   6.35 loss:0.184, accuracy:0.96
#   6.36 loss:0.0602, accuracy:0.99
#   6.37 loss:0.0731, accuracy:0.99
#   6.38 loss:0.0548, accuracy:1.0
#   6.39 loss:0.0905, accuracy:0.98
#   6.40 loss:0.173, accuracy:0.95
#   7. 1 loss:0.0345, accuracy:1.0
#   7. 2 loss:0.0805, accuracy:0.98
#   7. 3 loss:0.0504, accuracy:0.99
#   7. 4 loss:0.0967, accuracy:0.97
#   7. 5 loss:0.0714, accuracy:0.98
#   7. 6 loss:0.0315, accuracy:1.0
#   7. 7 loss:0.063, accuracy:0.98
#   7. 8 loss:0.0371, accuracy:1.0
#   7. 9 loss:0.0594, accuracy:0.99
#   7.10 loss:0.123, accuracy:0.96
#   7.11 loss:0.066, accuracy:0.99
#   7.12 loss:0.111, accuracy:0.97
#   7.13 loss:0.112, accuracy:0.96
#   7.14 loss:0.148, accuracy:0.94
#   7.15 loss:0.0236, accuracy:1.0
#   7.16 loss:0.0736, accuracy:0.98
#   7.17 loss:0.05, accuracy:0.99
#   7.18 loss:0.0728, accuracy:0.99
#   7.19 loss:0.122, accuracy:0.98
#   7.20 loss:0.0766, accuracy:1.0
#   7.21 loss:0.0757, accuracy:0.98
#   7.22 loss:0.115, accuracy:0.97
#   7.23 loss:0.0635, accuracy:0.99
#   7.24 loss:0.075, accuracy:0.99
#   7.25 loss:0.0355, accuracy:1.0
#   7.26 loss:0.0504, accuracy:0.99
#   7.27 loss:0.0829, accuracy:0.97
#   7.28 loss:0.0684, accuracy:0.98
#   7.29 loss:0.0857, accuracy:0.97
#   7.30 loss:0.069, accuracy:0.98
#   7.31 loss:0.0865, accuracy:0.98
#   7.32 loss:0.0476, accuracy:1.0
#   7.33 loss:0.104, accuracy:0.96
#   7.34 loss:0.101, accuracy:0.97
#   7.35 loss:0.177, accuracy:0.95
#   7.36 loss:0.065, accuracy:0.98
#   7.37 loss:0.067, accuracy:0.99
#   7.38 loss:0.055, accuracy:0.99
#   7.39 loss:0.082, accuracy:0.98
#   7.40 loss:0.18, accuracy:0.96
#   8. 1 loss:0.0309, accuracy:1.0
#   8. 2 loss:0.0686, accuracy:0.98
#   8. 3 loss:0.0551, accuracy:0.98
#   8. 4 loss:0.0889, accuracy:0.98
#   8. 5 loss:0.0713, accuracy:0.98
#   8. 6 loss:0.0341, accuracy:1.0
#   8. 7 loss:0.0711, accuracy:0.97
#   8. 8 loss:0.0497, accuracy:0.99
#   8. 9 loss:0.0599, accuracy:0.99
#   8.10 loss:0.115, accuracy:0.96
#   8.11 loss:0.0678, accuracy:0.99
#   8.12 loss:0.121, accuracy:0.97
#   8.13 loss:0.121, accuracy:0.95
#   8.14 loss:0.14, accuracy:0.96
#   8.15 loss:0.0261, accuracy:1.0
#   8.16 loss:0.0709, accuracy:0.98
#   8.17 loss:0.0534, accuracy:0.98
#   8.18 loss:0.0704, accuracy:0.99
#   8.19 loss:0.132, accuracy:0.98
#   8.20 loss:0.0988, accuracy:0.97
#   8.21 loss:0.0736, accuracy:0.98
#   8.22 loss:0.104, accuracy:0.97
#   8.23 loss:0.0587, accuracy:0.99
#   8.24 loss:0.0644, accuracy:0.98
#   8.25 loss:0.0318, accuracy:1.0
#   8.26 loss:0.0432, accuracy:0.99
#   8.27 loss:0.0781, accuracy:0.97
#   8.28 loss:0.0687, accuracy:0.99
#   8.29 loss:0.0729, accuracy:0.99
#   8.30 loss:0.067, accuracy:0.98
#   8.31 loss:0.0867, accuracy:0.98
#   8.32 loss:0.0412, accuracy:1.0
#   8.33 loss:0.0802, accuracy:0.98
#   8.34 loss:0.0922, accuracy:0.97
#   8.35 loss:0.169, accuracy:0.96
#   8.36 loss:0.0583, accuracy:0.99
#   8.37 loss:0.0626, accuracy:0.98
#   8.38 loss:0.0508, accuracy:0.99
#   8.39 loss:0.0772, accuracy:0.98
#   8.40 loss:0.181, accuracy:0.95
#   9. 1 loss:0.0331, accuracy:1.0
#   9. 2 loss:0.0709, accuracy:0.99
#   9. 3 loss:0.0596, accuracy:0.98
#   9. 4 loss:0.0827, accuracy:0.98
#   9. 5 loss:0.0628, accuracy:0.98
#   9. 6 loss:0.0314, accuracy:1.0
#   9. 7 loss:0.0472, accuracy:0.99
#   9. 8 loss:0.0452, accuracy:0.99
#   9. 9 loss:0.0504, accuracy:0.99
#   9.10 loss:0.101, accuracy:0.96
#   9.11 loss:0.0611, accuracy:1.0
#   9.12 loss:0.0999, accuracy:0.97
#   9.13 loss:0.115, accuracy:0.95
#   9.14 loss:0.109, accuracy:0.98
#   9.15 loss:0.0274, accuracy:1.0
#   9.16 loss:0.078, accuracy:0.97
#   9.17 loss:0.059, accuracy:0.99
#   9.18 loss:0.0752, accuracy:0.99
#   9.19 loss:0.124, accuracy:0.97
#   9.20 loss:0.0806, accuracy:0.99
#   9.21 loss:0.0719, accuracy:0.98
#   9.22 loss:0.123, accuracy:0.96
#   9.23 loss:0.0648, accuracy:0.99
#   9.24 loss:0.0674, accuracy:0.98
#   9.25 loss:0.0363, accuracy:1.0
#   9.26 loss:0.0502, accuracy:0.98
#   9.27 loss:0.0811, accuracy:0.98
#   9.28 loss:0.0615, accuracy:0.98
#   9.29 loss:0.0609, accuracy:0.99
#   9.30 loss:0.0641, accuracy:0.98
#   9.31 loss:0.0881, accuracy:0.98
#   9.32 loss:0.0452, accuracy:1.0
#   9.33 loss:0.0705, accuracy:0.98
#   9.34 loss:0.0939, accuracy:0.97
#   9.35 loss:0.177, accuracy:0.95
#   9.36 loss:0.0775, accuracy:0.97
#   9.37 loss:0.0526, accuracy:0.99
#   9.38 loss:0.0592, accuracy:0.98
#   9.39 loss:0.0685, accuracy:0.98
#   9.40 loss:0.166, accuracy:0.96
#  10. 1 loss:0.0399, accuracy:1.0
#  10. 2 loss:0.0863, accuracy:0.98
#  10. 3 loss:0.0726, accuracy:0.99
#  10. 4 loss:0.0776, accuracy:0.98
#  10. 5 loss:0.0669, accuracy:0.98
#  10. 6 loss:0.0311, accuracy:1.0
#  10. 7 loss:0.0401, accuracy:1.0
#  10. 8 loss:0.0345, accuracy:1.0
#  10. 9 loss:0.0413, accuracy:0.99
#  10.10 loss:0.0915, accuracy:0.97
#  10.11 loss:0.0625, accuracy:1.0
#  10.12 loss:0.1, accuracy:0.97
#  10.13 loss:0.131, accuracy:0.93
#  10.14 loss:0.106, accuracy:0.99
#  10.15 loss:0.0287, accuracy:1.0
#  10.16 loss:0.0675, accuracy:0.97
#  10.17 loss:0.0541, accuracy:0.99
#  10.18 loss:0.0752, accuracy:0.99
#  10.19 loss:0.119, accuracy:0.98
#  10.20 loss:0.069, accuracy:1.0
#  10.21 loss:0.0725, accuracy:0.98
#  10.22 loss:0.125, accuracy:0.95
#  10.23 loss:0.0646, accuracy:0.99
#  10.24 loss:0.0584, accuracy:0.99
#  10.25 loss:0.0307, accuracy:1.0
#  10.26 loss:0.0556, accuracy:0.98
#  10.27 loss:0.0799, accuracy:0.97
#  10.28 loss:0.0694, accuracy:0.98
#  10.29 loss:0.0539, accuracy:0.99
#  10.30 loss:0.0558, accuracy:1.0
#  10.31 loss:0.082, accuracy:0.99
#  10.32 loss:0.0524, accuracy:1.0
#  10.33 loss:0.0695, accuracy:0.98
#  10.34 loss:0.102, accuracy:0.96
#  10.35 loss:0.191, accuracy:0.96
#  10.36 loss:0.0909, accuracy:0.96
#  10.37 loss:0.0561, accuracy:0.99
#  10.38 loss:0.0606, accuracy:0.98
#  10.39 loss:0.0598, accuracy:0.98
#  10.40 loss:0.149, accuracy:0.94

# %% [markdown]
# ## Testing

# %%
# TODO
loss, accuracy, _ = feedforward_backprop(test_data, test_label, weights)
print('loss:{:.3}, accuracy:{}'.format(loss, accuracy))
# Out:
# loss:0.275, accuracy:0.923
